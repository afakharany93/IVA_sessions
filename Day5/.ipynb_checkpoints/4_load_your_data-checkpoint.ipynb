# %% [markdown]
# ## Setup

# %%
import numpy as np
import os
import cv2
import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# %%
print(tf.__version__)
print(cv2.__version__)
# Out:
# 2.6.0
# 4.5.3

# %%
def load_image(path, dim=None):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    if dim is not None:
        img = cv2.resize(img, dim)
    return img

# %% [markdown]
# ### Download the flowers dataset
#
# This tutorial uses a dataset of several thousand photos of flowers. The flowers dataset contains five sub-directories, one per class:
#
# ```
# flowers_photos/
#   daisy/
#   dandelion/
#   roses/
#   sunflowers/
#   tulips/
# ```

# %% [markdown]
# Note: all images are licensed CC-BY, creators are listed in the LICENSE.txt file.

# %%
#! wget https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz

# %%
#!tar zxvf flower_photos.tgz

# %%
# !ls flower_photos/
# Out:
# daisy  dandelion  LICENSE.txt  roses  sunflowers  tulips

# %%
data_dir_str = 'flower_photos/'

# %% [markdown]
# After downloading (218MB), you should now have a copy of the flower photos available. There are 3,670 total images:

# %%
image_count = len(list(glob.glob(data_dir_str+'*/*.jpg')))
print(image_count)
# Out:
# 3670

# %% [markdown]
# Each directory contains images of that type of flower. Here are some roses:

# %%
roses = list(glob.glob(data_dir_str+'roses/*'))
# print(roses)
plt.imshow(load_image(roses[0]))
plt.show()

# %%
plt.imshow(load_image(roses[1]))
plt.show()

# %% [markdown]
# ## Load data using a custom loop

# %%
img_height = 180
img_width = 180

claases_dir = glob.glob(data_dir_str+'/*')
print(claases_dir)

class_map = {}
count = 0
images_list = []
labels_list = []
for i in range(len(claases_dir)):
    class_folder = claases_dir[i].split('/')[-1]
    if '.txt' not in class_folder:
        print(class_folder)        
        class_map[count] = class_folder
        images_paths_list = glob.glob(claases_dir[i]+'/*')
        for j in images_paths_list:
            images_list.append(load_image(j, [img_height, img_width]))
            labels_list.append(count)
        count = count + 1
images = np.array(images_list)/255.0  
labels = np.array(labels_list)

images, labels = shuffle(images, labels)
train_data_size = int(0.7*images.shape[0])
print(images.shape)
print(labels.shape)
print(train_data_size)
train_images, test_images = images[:train_data_size], images[train_data_size:]
train_labels, test_labels = labels[:train_data_size], labels[train_data_size:]
# Out:
# ['flower_photos/tulips', 'flower_photos/sunflowers', 'flower_photos/LICENSE.txt', 'flower_photos/daisy', 'flower_photos/dandelion', 'flower_photos/roses']
# tulips
# sunflowers
# daisy
# dandelion
# roses
# (3670, 180, 180, 3)
# (3670,)
# 2569

# %%
print(class_map)
def get_class(c=[]):
    return [class_map[x] for x in c]
# Out:
# {0: 'tulips', 1: 'sunflowers', 2: 'daisy', 3: 'dandelion', 4: 'roses'}

# %% [markdown]
# ### Create a dataset

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32

# %% [markdown]
# It's good practice to use a validation split when developing your model. You will use 80% of the images for training and 20% for validation.

# %% [markdown]
# ### Visualize the data
#
# Here are the first nine images from the training dataset.

# %%
import matplotlib.pyplot as plt

lst = np.random.choice(range(len(train_labels)), size=9)
plt.figure(figsize=(10, 10))
for i in range(len(lst)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(train_images[lst[i]])
    plt.title(get_class([train_labels[lst[i]]]))
    plt.axis("off")

# %%
num_classes = 5

model = tf.keras.Sequential([
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])
# Out:
# 2021-10-04 22:49:37.866450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-04 22:49:37.870179: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-04 22:49:37.870498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-04 22:49:37.870964: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-04 22:49:37.871342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-04 22:49:37.871654: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-04 22:49:37.871953: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-04 22:49:38.107640: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-04 22:49:38.107969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-04 22:49:38.108263: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-04 22:49:38.108546: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9636 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:09:00.0, compute capability: 8.6

# %% [markdown]
# Choose the `tf.keras.optimizers.Adam` optimizer and `tf.keras.losses.SparseCategoricalCrossentropy` loss function. To view training and validation accuracy for each training epoch, pass the `metrics` argument to `Model.compile`.

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %% [markdown]
# Note: You will only train for a few epochs so this tutorial runs quickly.

# %%
model.fit(
  train_images, train_labels,
  validation_split=0.3,
  epochs=3
)
# Out:
# 2021-10-04 22:50:14.931820: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/3
# 2021-10-04 22:50:15.594154: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8204
# 2021-10-04 22:50:16.182393: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2021-10-04 22:50:16.662153: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 57/57 [==============================] - 3s 23ms/step - loss: 1.4822 - accuracy: 0.3348 - val_loss: 1.2898 - val_accuracy: 0.4929
# Epoch 2/3
# 57/57 [==============================] - 1s 15ms/step - loss: 1.1175 - accuracy: 0.5573 - val_loss: 1.1132 - val_accuracy: 0.5383
# Epoch 3/3
# 57/57 [==============================] - 1s 15ms/step - loss: 0.9554 - accuracy: 0.6240 - val_loss: 1.0674 - val_accuracy: 0.6057

# %%
predictions = np.argmax(model.predict(test_images[:9]), axis=1)
predictions = get_class(predictions)
labls = test_labels[:9]



plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(test_images[i])
    label = labls[i]
    plt.title(str(predictions[i]) + ' / '+ class_map[label])
    plt.axis("off")
